# %%
import pandas as pd

import numpy as np

# %%
# Out:
#        CDM project reference number HostParty     Issuance process ID  \
# 0                              8784        IN    4KEarth1568615888.93
# 1                              3779        IN     4KEarth1568616446.5
# 2                              3541        IN    4KEarth1585297661.77
# 3                              8712        TH    4KEarth1596186178.27
# 4                              4818        IN    4KEarth1599113457.49
# ...                             ...       ...                     ...
# 12543                          4776        IN  sergeyf731618828753.52
# 12544                          4776        IN  sergeyf731618828921.37
# 12545                          7834        CN   sergeyf731650363867.4
# 12546                          7981        IN    slenzen1552989570.98
# 12547                          1506        BR      sleyh1563531122.32
#
#       Issuance date Monitoring report started Monitoring report ended  \
# ...
